# %%
import pandas as pd

# %%
df = pd.read_fwf('ES2012.txt')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495547 entries, 0 to 1495546
# Data columns (total 50 columns):
#  #   Column                                                                                                         Non-Null Count    Dtype
# ---  ------                                                                                                         --------------    -----
#  0   Bairros                                                                                                        0 non-null        float64
#  1   SP;Bairros Fortaleza;Bairros RJ;Causa                                                                          1495547 non-null  object
#  2   Afastamento 1;Causa Afastamento 2;Causa Afastamento                                                            1495547 non-null  object
#  3   3;Motivo Desligamento;CBO Ocupa��o                                                                             1495547 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Bairros', 'SP;Bairros Fortaleza;Bairros RJ;Causa',
#        'Afastamento 1;Causa Afastamento 2;Causa Afastamento',
#        '3;Motivo Desligamento;CBO Ocupa��o', '2002;CNAE', '2.0', 'Classe;CNAE',
#        '95 Classe;Distritos SP;V�nculo Ativo 31/12;Faixa Et�ria;Faixa Hora Contrat;Faixa Remun Dezem (SM);Faixa Remun',
#        'M�dia', '(SM);Faixa Tempo', 'Emprego;Escolaridade', 'ap�s',
#        '2005;Qtd Hora', 'Contr;Idade;Ind', 'CEI', 'Vinculado;Ind',
#        'Simples;M�s', 'Admiss�o;M�s', 'Desligamento;Mun',
#        'Trab;Munic�pio;Nacionalidade;Natureza', 'Jur�dica;Ind', 'Portador',
#        'Defic;Qtd', 'Dias', 'Afastamento;Ra�a', 'Cor;Regi�es', 'Adm', 'DF;Vl',
#        'Remun', 'Dezembro', 'Nom;Vl', 'Remun.1', 'Dezembro.1', '(SM);Vl',
#        'Remun.2', 'M�dia.1', 'Nom;Vl.1', 'Remun.3', 'M�dia.2', '(SM);CNAE',
#        '2.0.1', 'Subclasse;Sexo', 'Trabalhador;Tamanho',
#        'Estabelecimento;Tempo', 'Emprego;Tipo', 'Admiss�o;Tipo', 'Estab;Tipo',
# ...

# %%
df[df.head().isna() == False]
# Out:
#          Bairros SP;Bairros Fortaleza;Bairros RJ;Causa  \
# 0            NaN       {� class};           {� class};
# 1            NaN       {� class};           {� class};
# 2            NaN       {� class};           {� class};
# 3            NaN       {� class};           {� class};
# 4            NaN       {� class};           {� class};
# ...          ...                                   ...
# 1495542      NaN                                   NaN
# 1495543      NaN                                   NaN
# 1495544      NaN                                   NaN
# 1495545      NaN                                   NaN
# 1495546      NaN                                   NaN
#
#         Afastamento 1;Causa Afastamento 2;Causa Afastamento  \
# 0                {� class};99;99;99;11;622020;01334;01392;
# 1                {� class};99;99;99;21;622020;01334;01392;
# 2                {� class};99;99;99;12;715210;47440;52442;
# 3                {� class};99;99;99;21;717020;47440;52442;
# ...

# %%
df2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1454537 entries, 0 to 1454536
# Data columns (total 70 columns):
#  #   Column                                                                                                                                                                                                                                    Non-Null Count    Dtype
# ---  ------                                                                                                                                                                                                                                    --------------    -----
#  0   Bairros                                                                                                                                                                                                                                   1454537 non-null  object
# ...

# %%
df2015.columns
# Out:
# Index(['Bairros',
#        'SP;Bairros Fortaleza;Bairros RJ;Causa Afastamento 1;Causa Afastamento 2;Causa',
#        'Afastamento', '3;Motivo',
#        'Desligamento;CBO Ocupa��o 2002;CNAE 2.0 Classe;CNAE 95 Classe;Distritos SP;V�nculo Ativo 31/12;Faixa Et�ria;Faixa',
#        'Hora',
#        'Contrat;Faixa Remun Dezem (SM);Faixa Remun M�dia (SM);Faixa Tempo Emprego;Escolaridade ap�s 2005;Qtd Hora Contr;Idade;Ind CEI Vinculado;Ind Simples;M�s Admiss�o;M�s Desligamento;Mun Trab;Munic�pio;Nacionalidade;Natureza Jur�dica;Ind',
#        'Portador', 'Defic;Qtd', 'Dias', 'Afastamento;Ra�a', 'Cor;Regi�es',
#        'Adm', 'DF;Vl', 'Remun', 'Dezembro', 'Nom;Vl', 'Remun.1', 'Dezembro.1',
#        '(SM);Vl', 'Remun.2', 'M�dia', 'Nom;Vl.1', 'Remun.3', 'M�dia.1',
#        '(SM);CNAE', '2.0', 'Subclasse;Sexo', 'Trabalhador;Tamanho',
#        'Estabelecimento;Tempo', 'Emprego;Tipo', 'Admiss�o;Tipo', 'Estab;Tipo',
#        'Estab;Tipo.1', 'Defic;Tipo', 'V�nculo;IBGE', 'Subsetor;Vl', 'Rem',
# ...

# %%
df2015.head()
# Out:
#    Bairros  \
# 0  {� c;{�
# 1  {� c;{�
# 2  {� c;{�
# 3  {� c;{�
# 4  {� c;{�
#
#   SP;Bairros Fortaleza;Bairros RJ;Causa Afastamento 1;Causa Afastamento 2;Causa  \
# 0  c;{� c;99;99;99;12;711115;23915;26913;        ...
# 1  c;{� c;99;99;99;11;516610;41204;45217;        ...
# 2  c;{� c;99;99;99;11;784105;20622;24724;        ...
# 3  c;{� c;99;99;99;11;513615;56112;55212;        ...
# 4  c;{� c;99;99;99;11;622110;11119;15911;        ...
#
#    Afastamento 3;Motivo  \
# 0          NaN      01;
# 1          NaN      01;
# 2          NaN      01;
# 3          NaN      01;
# 4          NaN      01;
#
#   Desligamento;CBO Ocupa��o 2002;CNAE 2.0 Classe;CNAE 95 Classe;Distritos SP;V�nculo Ativo 31/12;Faixa Et�ria;Faixa  \
# 0  44;  20;0;0;03;04;320390;320390;10;2062;0;   0...
# 1  44;  56;0;0;00;10;320520;320520;10;2062;0;   0...
# 2  44;  51;0;1;00;01;320520;320520;10;2062;0;   0...
# 3  44;  29;0;1;00;11;320530;320530;10;2062;0;   0...
# ...

# %%
df2015.iloc[:,6]
# Out:
# 0          01;05;     0,9;02;01;CNPJ;00;10;02;00000000000...
# 1          01;07;    45,2;00;01;CNPJ;00;10;15;00000000128...
# 2          01;03;     3,4;00;01;CNPJ;00;10;10;00000000000...
# 3          01;02;    42,3;00;01;CNPJ;00;10;21;00000000174...
# 4          01;02;    31,6;00;01;CNPJ;00;10;13;00000000078...
#                                  ...
# 1454532    02;10;     1,6;02;01;CNPJ;00;90;01;00000000000...
# 1454533    02;10;    55,8;00;01;CNPJ;00;10;01;00000001215...
# 1454534    02;10;    10,9;02;01;CNPJ;00;10;21;00000000000...
# 1454535    02;08;   178,9;00;01;CNPJ;00;10;23;00000000239...
# 1454536    02;08;    83,1;00;01;CNPJ;00;10;23;00000000045...
# Name: Contrat;Faixa Remun Dezem (SM);Faixa Remun M�dia (SM);Faixa Tempo Emprego;Escolaridade ap�s 2005;Qtd Hora Contr;Idade;Ind CEI Vinculado;Ind Simples;M�s Admiss�o;M�s Desligamento;Mun Trab;Munic�pio;Nacionalidade;Natureza Jur�dica;Ind, Length: 1454537, dtype: object

# %%
colunas = ['Portador','Outubro']

# %%
df2015_colunas = pd.read_fwf('ES2015.txt', usecols=colunas)

# %%
df2015_colunas[df2015_colunas['Portador'].isna() == True]
# Out:
#          Portador  Outubro
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
# ...           ...      ...
# 1454532       NaN      NaN
# 1454533       NaN      NaN
# 1454534       NaN      NaN
# 1454535       NaN      NaN
# 1454536       NaN      NaN
#
# [1454537 rows x 2 columns]

# %%
dfsep = pd.read_fwf('ES2012.txt', sep=';')

# %%
dfsep.to_csv('esconv.csv', index=False)

# %%
df.head()
# Out:
#    Bairros SP;Bairros Fortaleza;Bairros RJ;Causa  \
# 0      NaN       {� class};           {� class};
# 1      NaN       {� class};           {� class};
# 2      NaN       {� class};           {� class};
# 3      NaN       {� class};           {� class};
# 4      NaN       {� class};           {� class};
#
#   Afastamento 1;Causa Afastamento 2;Causa Afastamento  \
# 0          {� class};99;99;99;11;622020;01334;01392;
# 1          {� class};99;99;99;21;622020;01334;01392;
# 2          {� class};99;99;99;12;715210;47440;52442;
# 3          {� class};99;99;99;21;717020;47440;52442;
# 4          {� class};99;99;99;10;783210;81125;70408;
#
#   3;Motivo Desligamento;CBO Ocupa��o  2002;CNAE  2.0 Classe;CNAE  \
# 0        {� class};0;05;06;00;02;03;        NaN  NaN    01;  44;
# 1        {� class};0;04;06;00;01;02;        NaN  NaN    01;  44;
# 2        {� class};0;05;06;00;03;01;        NaN  NaN    01;  44;
# 3        {� class};0;05;06;00;01;01;        NaN  NaN    01;  44;
# ...

# %%
dfcsv = pd.read_csv('esconv.csv', sep=';')
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfcsv.columns
# Out:
# Index(['Bairros,SP', 'Bairros Fortaleza', 'Bairros RJ', 'Causa,Afastamento 1',
#        'Causa Afastamento 2', 'Causa Afastamento,3', 'Motivo Desligamento',
#        'CBO Ocupa��o,2002', 'CNAE,2.0,Classe', 'CNAE,95 Classe',
#        'Distritos SP', 'V�nculo Ativo 31/12', 'Faixa Et�ria',
#        'Faixa Hora Contrat', 'Faixa Remun Dezem (SM)',
#        'Faixa Remun,M�dia,(SM)', 'Faixa Tempo,Emprego',
#        'Escolaridade,ap�s,2005', 'Qtd Hora,Contr', 'Idade',
#        'Ind,CEI,Vinculado', 'Ind,Simples', 'M�s,Admiss�o', 'M�s,Desligamento',
#        'Mun,Trab', 'Munic�pio', 'Nacionalidade', 'Natureza,Jur�dica',
#        'Ind,Portador,Defic', 'Qtd,Dias,Afastamento', 'Ra�a,Cor',
#        'Regi�es,Adm,DF', 'Vl,Remun,Dezembro,Nom', 'Vl,Remun.1,Dezembro.1,(SM)',
#        'Vl,Remun.2,M�dia.1,Nom', 'Vl.1,Remun.3,M�dia.2,(SM)',
#        'CNAE,2.0.1,Subclasse', 'Sexo,Trabalhador', 'Tamanho,Estabelecimento',
#        'Tempo,Emprego', 'Tipo,Admiss�o', 'Tipo,Estab', 'Tipo,Estab.1',
# ...

# %%
dfsep15 = pd.read_fwf('ES2015.txt', sep=';')

# %%
dfsep15.columns
# Out:
# Index(['Bairros',
#        'SP;Bairros Fortaleza;Bairros RJ;Causa Afastamento 1;Causa Afastamento 2;Causa',
#        'Afastamento', '3;Motivo',
#        'Desligamento;CBO Ocupa��o 2002;CNAE 2.0 Classe;CNAE 95 Classe;Distritos SP;V�nculo Ativo 31/12;Faixa Et�ria;Faixa',
#        'Hora',
#        'Contrat;Faixa Remun Dezem (SM);Faixa Remun M�dia (SM);Faixa Tempo Emprego;Escolaridade ap�s 2005;Qtd Hora Contr;Idade;Ind CEI Vinculado;Ind Simples;M�s Admiss�o;M�s Desligamento;Mun Trab;Munic�pio;Nacionalidade;Natureza Jur�dica;Ind',
#        'Portador', 'Defic;Qtd', 'Dias', 'Afastamento;Ra�a', 'Cor;Regi�es',
#        'Adm', 'DF;Vl', 'Remun', 'Dezembro', 'Nom;Vl', 'Remun.1', 'Dezembro.1',
#        '(SM);Vl', 'Remun.2', 'M�dia', 'Nom;Vl.1', 'Remun.3', 'M�dia.1',
#        '(SM);CNAE', '2.0', 'Subclasse;Sexo', 'Trabalhador;Tamanho',
#        'Estabelecimento;Tempo', 'Emprego;Tipo', 'Admiss�o;Tipo', 'Estab;Tipo',
#        'Estab;Tipo.1', 'Defic;Tipo', 'V�nculo;IBGE', 'Subsetor;Vl', 'Rem',
# ...

# %%
dfsep15.to_csv('dfsep15csv.csv', index=False)

# %%
df15csv = pd.read_csv('dfsep15csv.csv', sep=';')
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfgerente = df15csv[df15csv['CBO Ocupa��o 2002'] == 142510]

# %%
df15csv.columns
# Out:
# Index(['Bairros,SP', 'Bairros Fortaleza', 'Bairros RJ', 'Causa Afastamento 1',
#        'Causa Afastamento 2', 'Causa,Afastamento,3', 'Motivo,Desligamento',
#        'CBO Ocupa��o 2002', 'CNAE 2.0 Classe', 'CNAE 95 Classe',
#        'Distritos SP', 'V�nculo Ativo 31/12', 'Faixa Et�ria',
#        'Faixa,Hora,Contrat', 'Faixa Remun Dezem (SM)',
#        'Faixa Remun M�dia (SM)', 'Faixa Tempo Emprego',
#        'Escolaridade ap�s 2005', 'Qtd Hora Contr', 'Idade',
#        'Ind CEI Vinculado', 'Ind Simples', 'M�s Admiss�o', 'M�s Desligamento',
#        'Mun Trab', 'Munic�pio', 'Nacionalidade', 'Natureza Jur�dica',
#        'Ind,Portador,Defic', 'Qtd,Dias,Afastamento', 'Ra�a,Cor',
#        'Regi�es,Adm,DF', 'Vl,Remun,Dezembro,Nom', 'Vl,Remun.1,Dezembro.1,(SM)',
#        'Vl,Remun.2,M�dia,Nom', 'Vl.1,Remun.3,M�dia.1,(SM)',
#        'CNAE,2.0,Subclasse', 'Sexo,Trabalhador', 'Tamanho,Estabelecimento',
#        'Tempo,Emprego', 'Tipo,Admiss�o', 'Tipo,Estab', 'Tipo,Estab.1',
# ...

# %%
dfgerente[['Sexo,Trabalhador','Faixa Remun M�dia (SM)','CBO Ocupa��o 2002','Vl.9,Rem.10,Novembro,CC','Vl,Rem,Janeiro,CC']]
# Out:
#         Sexo,Trabalhador  Faixa Remun M�dia (SM) CBO Ocupa��o 2002  \
# 148568              ,,01                      99            142510
# 236191              ,,01                       8            142510
# 278416              ,,01                       7            142510
# 278517              ,,01                       8            142510
# 920426              ,,01                       4            142510
# 1313869             ,,02                       4            142510
#
#                                    Vl.9,Rem.10,Novembro,CC Vl,Rem,Janeiro,CC
# 148568   000000000000,00",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...   000000000000,00
# 236191   000000000000,00",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...   000000006248,00
# 278416   000000000000,00",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...   000000004000,00
# 278517   000000000000,00",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...   000000006125,10
# 920426   000000000830,36",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...   000000000000,00
# ...

# %%
df15csv[['Faixa Remun Dezem (SM)','Faixa Remun M�dia (SM)','Vl,Remun,Dezembro,Nom', 'Sexo,Trabalhador', 'Vl,Rem,Janeiro,CC', 'Vl.5,Rem.6,Julho,CC','CBO Ocupa��o 2002']]
# Out:
#          Faixa Remun Dezem (SM)  Faixa Remun M�dia (SM) Vl,Remun,Dezembro,Nom  \
# 0                             0                       3         0000000000,00
# 1                             0                       3         0000000000,00
# 2                             0                      99         0000000000,00
# 3                             0                       4         0000000000,00
# 4                             0                       2         0000000000,00
# ...                         ...                     ...                   ...
# 1454532                       9                       8         0000007848,59
# 1454533                      11                      10         0000012472,16
# 1454534                       3                       2         0000000884,92
# 1454535                       9                       8         0000005963,60
# 1454536                       8                       6         0000004113,22
#
# ...

# %%
dfgerente[dfgerente['Sexo,Trabalhador'] == ',,01']
# Out:
#        Bairros,SP Bairros Fortaleza Bairros RJ  Causa Afastamento 1  \
# 148568       {� c              {�,c       {� c                   99
# 236191       {� c              {�,c       {� c                   99
# 278416       {� c              {�,c       {� c                   99
# 278517       {� c              {�,c       {� c                   99
# 920426       {� c              {�,c       {� c                   20
#
#         Causa Afastamento 2  Causa,Afastamento,3  Motivo,Desligamento  \
# 148568                   99                   99                   31
# 236191                   99                   99                   31
# 278416                   99                   99                   21
# 278517                   99                   99                   21
# 920426                   99                   99                    0
#
#        CBO Ocupa��o 2002  CNAE 2.0 Classe  CNAE 95 Classe  ...  \
# 148568            142510            45307           50300  ...
# ...

# %%
dfgerente_filter = dfgerente[['Sexo,Trabalhador','Faixa Remun M�dia (SM)','CBO Ocupa��o 2002']]

# %%
dfgerente_filter
# Out:
#          sexo  remunera ocupacao
# 148568   ,,01       NaN   142510
# 236191   ,,01  5.166,00   142510
# 278416   ,,01  4.728,00   142510
# 278517   ,,01  5.166,00   142510
# 920426   ,,01  3.152,00   142510
# 1313869  ,,02  3.152,00   142510

# %%
dfgerente_filter.rename(columns={'Faixa Remun M�dia (SM)': 'remunera','CBO Ocupa��o 2002': 'ocupacao' }, inplace=True)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#df['dfgerente_filter']= pd.to_numeric(df['Climate'].str.replace(',','.'),errors='coerce')
dfgerente_filter['Faixa Remun M�dia (SM)'] = pd.cut(dfgerente_filter['Faixa Remun M�dia (SM)'], bins=[4,7,8,9,99], right=False, labels=["3.152,00", "4.728,00", "5.166,00", "0.00"])
dfgerente_filter.head()
# Out:
# <ipython-input-171-f3e49f7f83b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfgerente_filter['Faixa Remun M�dia (SM)'] = pd.cut(dfgerente_filter['Faixa Remun M�dia (SM)'], bins=[4,7,8,9,99], right=False, labels=["3.152,00", "4.728,00", "5.166,00", "0.00"])
#        Sexo,Trabalhador Faixa Remun M�dia (SM) CBO Ocupa��o 2002
# 148568             ,,01                    NaN            142510
# 236191             ,,01               5.166,00            142510
# 278416             ,,01               4.728,00            142510
# 278517             ,,01               5.166,00            142510
# 920426             ,,01               3.152,00            142510

# %%
dfgerente_filter
# Out:
#         Sexo,Trabalhador Faixa Remun M�dia (SM) CBO Ocupa��o 2002
# 148568              ,,01                    NaN            142510
# 236191              ,,01               5.166,00            142510
# 278416              ,,01               4.728,00            142510
# 278517              ,,01               5.166,00            142510
# 920426              ,,01               3.152,00            142510
# 1313869             ,,02               3.152,00            142510

# %%
pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 212.4 MB 105 kB/s eta 0:00:01     |███████████████████████▍        | 155.3 MB 1.3 MB/s eta 0:00:46
# ...
#      |████████████████████████████████| 198 kB 987 kB/s eta 0:00:01
# ...
#   Created wheel for pyspark: filename=pyspark-3.1.2-py2.py3-none-any.whl size=212880769 sha256=0e15ef68ecc8a1354f822b98e6446284dcffe4a086c5041050e1fe231fda0db7
#   Stored in directory: /Users/dfso/Library/Caches/pip/wheels/df/88/9e/58ef1f74892fef590330ca0830b5b6d995ba29b44f977b3926
# Successfully built pyspark
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.appName("demo-app").getOrCreate()

# %%
csvFile = spark.read.csv('dfgerente.csv', header=True, inferSchema=True)
csvFile.write.saveAsTable("dfgerente")

# %%
teste = spark.sql("SELECT max(remunera) as remu FROM dfgerente where remunera <> 'null' ")
teste.show()
# Out:
# +--------+
# |    remu|
# +--------+
# |5.166,00|
# +--------+

# %%
# Out:
# +----+
# |Sexo|
# +----+
# |,,01|
# |,,01|
# |,,01|
# |,,01|
# |,,01|
# |,,02|
# +----+

# %%
pip install pyftpdlib
# Out:
# ...
#      |████████████████████████████████| 188 kB 878 kB/s eta 0:00:01
# ...
#   Created wheel for pyftpdlib: filename=pyftpdlib-1.5.6-py3-none-any.whl size=125586 sha256=6a934e5b0afc46bb74a590f34357e3ff1bf8e547e50f859777c2277b0ebe9152
#   Stored in directory: /Users/dfso/Library/Caches/pip/wheels/a0/24/20/773d4186a5b61c8bdb2e6059a3da4d6b0afc56a9e5f436b81a
# Successfully built pyftpdlib
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ftplib import FTP
with FTP('ftp.mtps.gov.br') as ftp:
    ftp.login()
    ftp.cwd('pdet/microdados/RAIS/2015')
#dir_list = []
    ftp.dir()
# Out:
# 09-16-16  05:44PM              5545547 AC2015.7z
# 09-16-16  05:44PM             20891582 AL2015.7z
# 09-16-16  05:44PM             28911533 AM2015.7z
# 09-16-16  05:44PM              5241152 AP2015.7z
# 09-16-16  05:45PM            107438864 BA2015.7z
# 09-16-16  05:38PM             66606094 CE2015.7z
# 09-16-16  05:38PM             54492170 DF2015.7z
# 09-16-16  05:38PM             49742683 ES2015.7z
# 09-16-16  05:25PM             91120534 ESTB2015.7z
# 09-16-16  05:38PM             81068551 GO2015.7z
# 09-16-16  05:39PM             28269732 MA2015.7z
# 09-16-16  05:39PM            261522357 MG2015.7z
# 09-16-16  05:39PM             35593084 MS2015.7z
# 09-16-16  05:39PM             48095950 MT2015.7z
# 09-16-16  05:40PM             54273590 PA2015.7z
# 09-16-16  05:40PM             25582997 PB2015.7z
# 09-19-16  01:15PM             75698676 PE2015.7z
# 09-19-16  01:38PM             17693037 PI2015.7z
# 09-16-16  05:40PM            176053497 PR2015.7z
# ...
